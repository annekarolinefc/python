# %% [markdown]
# # GRAFICOS

# %% [markdown]
# *   matplotlib
# *   Seaborn

# %% [markdown]
# ## Gráfico de linha

# %%
import pandas as pd

from matplotlib import pyplot as plt
from matplotlib import rcParams

#import seaborn as sns

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5,4
#sns.set_style('whitegrid')

# %%
# desenhando um grafico de linhas usando o matplotlib
x = range(1, 10)
y = [1, 2, 3, 4, 0, 4, 3, 2, 1]

plt.plot(x, y)

# %%
# usando Pandas
df = carros[['x','y','z']]
df.plot()

# %% [markdown]
# ## Gráfico de barra

# %%
import pandas

from matplotlib import pyplot as plt 
from matplotlib import rxParams

#import seaborn as sns

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4

# %%
x = range(1, 10)
y = [1, 2, 3, 4, 0, 4, 3, 2, 1]
plt.bar(x, y)
# Out:
# <BarContainer object of 9 artists>

# %%
# USANDO PANDAS
carros.columns = ['col1', 'col2', 'col3']
z = carros['col3']

z.plot(kind='bar') #barra vertical
z.plot(kind='barh')#barra horizontal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Anne Karoline\workspace 2022\00-Projetos-2022\python\listas-de-exercicios\lista-02\graficos.ipynb Célula: 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Anne%20Karoline/workspace%202022/00-Projetos-2022/python/listas-de-exercicios/lista-02/graficos.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> # USANDO PANDAS
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Anne%20Karoline/workspace%202022/00-Projetos-2022/python/listas-de-exercicios/lista-02/graficos.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> carros.columns = ['col1', 'col2', 'col3']
#       <a href='vscode-notebook-cell:/c%3A/Users/Anne%20Karoline/workspace%202022/00-Projetos-2022/python/listas-de-exercicios/lista-02/graficos.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> z = carros['col3']
# ...

# %%
#SALVANDO GRAFICO
plt.savefig('nome.png')

! dir

# %% [markdown]
# ## FORMATAÇÃO DE GRAFICO

# %% [markdown]
# https://www.linkedin.com/learning/python-para-ciencia-de-dados-formacao-basica/mergulhando-no-matplotlib?autoSkip=true&autoplay=true&resume=false
